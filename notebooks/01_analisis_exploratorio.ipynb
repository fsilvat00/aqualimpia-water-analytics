# %%
# Proyecto Analítico: Tratamiento de Aguas Residuales - AquaLimpia S. A.
**Autor:** Francisco Silva  
**Carrera:** Ingeniería en Informática / Ciencia de Datos  
**Fecha:** Septiembre 2026  

---
### Objetivos
1. Diagnosticar los incumplimientos normativos de DBO de salida en las plantas Norte, Centro y Sur.
2. Analizar la relación entre caudal hídrico, carga orgánica y consumo energético de aireación[cite: 1].
3. Aplicar funciones modulares con NumPy y SciPy, y serializar el pipeline con Joblib[cite: 1].

# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append(os.path.abspath('..'))
from src.water_analytics import (
    calcular_eficiencia_remocion,
    evaluar_anomalias_scipy,
    clasificar_alertas_operativas,
    exportar_reportes,
    serializar_procesador
)

sns.set_theme(style="whitegrid")

# %%
df = pd.read_excel('../data/dataset_set_A_aguas_residuales.xlsx')
df['fecha_registro'] = pd.to_datetime(df['fecha_registro'])

df['eficiencia_DBO'] = calcular_eficiencia_remocion(df)

z_scores, anomalias = evaluar_anomalias_scipy(df)
df['z_score_DBO_salida'] = z_scores
df['es_anomalia'] = anomalias

df['alerta_operativa'] = clasificar_alertas_operativas(df)

df.head()
